# %%
import pandas as pd
import os
import glob
import matplotlib.pyplot as plt

# %% [markdown]
# We want to look the most "abrupt" scenario but first we need to find him

# %%
fichiers = [i for i in os.listdir('C:/Users/cjoly/projet/Net1_CMH/') if os.path.isdir(os.path.join('C:/Users/cjoly/projet/Net1_CMH/', i))]
fichiers
# Out:
# ['Scenario-1',
#  'Scenario-10',
#  'Scenario-100',
#  'Scenario-1000',
#  'Scenario-101',
#  'Scenario-102',
#  'Scenario-103',
#  'Scenario-104',
#  'Scenario-105',
#  'Scenario-106',
#  'Scenario-107',
#  'Scenario-108',
#  'Scenario-109',
#  'Scenario-11',
#  'Scenario-110',
#  'Scenario-111',
#  'Scenario-112',
#  'Scenario-113',
#  'Scenario-114',
#  'Scenario-115',
#  'Scenario-116',
#  'Scenario-117',
#  'Scenario-118',
#  'Scenario-119',
#  'Scenario-12',
#  'Scenario-120',
#  'Scenario-121',
#  'Scenario-122',
#  'Scenario-123',
#  'Scenario-124',
#  'Scenario-125',
#  'Scenario-126',
#  'Scenario-127',
#  'Scenario-128',
#  'Scenario-129',
#  'Scenario-13',
#  'Scenario-130',
#  'Scenario-131',
#  'Scenario-132',
#  'Scenario-133',
#  'Scenario-134',
#  'Scenario-135',
#  'Scenario-136',
#  'Scenario-137',
#  'Scenario-138',
#  'Scenario-139',
#  'Scenario-14',
#  'Scenario-140',
#  'Scenario-141',
#  'Scenario-142',
#  'Scenario-143',
#  'Scenario-144',
# ...

# %%
test ='Scenario-234'
test.find('-')
int(test[test.find('-') + 1:])
# Out:
# 234

# %%
os.listdir(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-506/Leaks')
# Out:
# ['Leak_10_demand.csv', 'Leak_10_info.csv']

# %%
fichiers=[]
e=0
for i in range(1,1001):
    if os.listdir(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-{i}/Leaks')==[] :
        e+=1
    else :
        fichiers.append(glob.glob(os.path.join(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-{i}/Leaks', "*info.csv")))
e
# Out:
# 259

# %%
fichiers
# Out:
# [['C:/Users/cjoly/projet/Net1_CMH/Scenario-1/Leaks\\Leak_13_info.csv'],
#  ['C:/Users/cjoly/projet/Net1_CMH/Scenario-2/Leaks\\Leak_31_info.csv'],
#  ['C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Leaks\\Leak_21_info.csv',
#   'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Leaks\\Leak_2_info.csv'],
#  ['C:/Users/cjoly/projet/Net1_CMH/Scenario-5/Leaks\\Leak_22_info.csv'],
#  ['C:/Users/cjoly/projet/Net1_CMH/Scenario-6/Leaks\\Leak_22_info.csv'],
#  ['C:/Users/cjoly/projet/Net1_CMH/Scenario-8/Leaks\\Leak_21_info.csv'],
#  ['C:/Users/cjoly/projet/Net1_CMH/Scenario-9/Leaks\\Leak_23_info.csv',
#   'C:/Users/cjoly/projet/Net1_CMH/Scenario-9/Leaks\\Leak_31_info.csv'],
#  ['C:/Users/cjoly/projet/Net1_CMH/Scenario-13/Leaks\\Leak_21_info.csv'],
#  ['C:/Users/cjoly/projet/Net1_CMH/Scenario-15/Leaks\\Leak_13_info.csv'],
#  ['C:/Users/cjoly/projet/Net1_CMH/Scenario-16/Leaks\\Leak_13_info.csv',
#   'C:/Users/cjoly/projet/Net1_CMH/Scenario-16/Leaks\\Leak_32_info.csv'],
# ...

# %%
for j in range (len(fichiers)) :
    for k in range(len(fichiers[j])):
        fichiers[j][k]=pd.read_csv(fichiers[j][k])

# %%
for j in range (len(fichiers)) :
    for k in range(len(fichiers[j])):
        fichiers[j][k].columns=["Description","Value"]

# %%
liste=[]
for j in range (len(fichiers)) :
    for k in range(len(fichiers[j])):
        if fichiers[j][k]['Value'][3]== ' incipient' :
            liste.append([j,k])

# %%
liste_d=[]
for i in liste :
    liste_d.append(fichiers[i[0]][i[1]]['Value'][2])

# %%
liste
# Out:
# [[0, 0],
#  [1, 0],
#  [2, 0],
#  [2, 1],
#  [5, 0],
#  [6, 0],
#  [6, 1],
#  [7, 0],
#  [8, 0],
#  [10, 0],
#  [11, 1],
#  [17, 0],
#  [18, 0],
#  [19, 0],
#  [20, 0],
#  [22, 0],
#  [23, 0],
#  [26, 0],
#  [27, 0],
#  [28, 0],
#  [31, 1],
#  [34, 0],
#  [34, 1],
#  [35, 0],
#  [36, 0],
#  [37, 0],
#  [39, 0],
#  [40, 0],
#  [41, 1],
#  [42, 0],
#  [43, 1],
#  [44, 0],
#  [45, 0],
#  [46, 1],
#  [47, 0],
#  [49, 0],
#  [50, 0],
#  [50, 1],
#  [52, 0],
#  [53, 0],
#  [57, 0],
#  [58, 0],
#  [60, 0],
#  [61, 1],
#  [64, 1],
#  [65, 0],
#  [66, 0],
#  [67, 0],
#  [69, 0],
#  [69, 1],
#  [70, 0],
#  [70, 1],
#  [72, 0],
#  [73, 0],
#  [74, 0],
#  [74, 1],
#  [76, 0],
#  [79, 0],
#  [80, 1],
#  [88, 1],
#  [89, 0],
#  [90, 0],
#  [91, 0],
#  [93, 0],
#  [94, 0],
#  [96, 0],
#  [97, 0],
#  [98, 0],
#  [99, 0],
#  [102, 0],
#  [103, 0],
#  [107, 0],
#  [109, 0],
#  [114, 0],
#  [119, 0],
#  [121, 0],
#  [122, 0],
#  [125, 0],
#  [126, 0],
#  [131, 0],
#  [133, 0],
#  [134, 0],
# ...

# %%
d=max(liste_d)
d
# Out:
# ' 0.199530584388'

# %%
a=liste_d.index(d)
a
# Out:
# 152

# %%
liste[228]
# Out:
# [368, 0]

# %%
fichiers[228]
# Out:
# [      Description             Value
#  0      Leak Node                 32
#  1      Leak Area    0.0209046209532
#  2  Leak Diameter     0.163145985385
#  3      Leak Type             abrupt
#  4     Leak Start               7897
#  5       Leak End              14790
#  6      Peak Time               7897]

# %% [markdown]
# We can begin visualization

# %%
dl=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-5/Leaks/Leak_22_demand.csv')
plt.plot(dl.index, dl["Value"] )

# %%
dd=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-5/Demands/Node_10.csv')
plt.plot(dd.index, dd["Value"] )

# %%
for i in range(1,1000):
    dp=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-{i}/Demands/Node_10.csv')
    plt.plot(dp.index, dp["Value"])

# %% [markdown]
# demands on node 10 is null vor every scenario

# %%
dd=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-16/Demands/Node_11.csv')
plt.plot(dd.index, dd["Value"] )

# %%
#quasiment nulle mais on voit quand même la fuite

# %%
dd=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-1/Demands/Node_21.csv')
plt.plot(dd.index, dd["Value"] )

# %%
dd=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-1/Demands/Node_21.csv')
plt.plot(dd.index, dd["Value"] )

# %%
dd=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-/Demands/Node_31.csv')
plt.plot(dd.index, dd["Value"] )

# %%
dd=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-504/Demands/Node_31.csv')
plt.plot(dd.index, dd["Value"] )

# %%
df=pd.read_csv('C:/Users/cjoly/projet/Net1_CMH/Scenario-2/Flows/link_21.csv')
plt.plot(df.index, df["Value"] )

# %%
df=pd.read_csv('C:/Users/cjoly/projet/Net1_CMH/Scenario-2/Flows/link_22.csv')
plt.plot(df.index, df["Value"] )

# %%
df=pd.read_csv('C:/Users/cjoly/projet/Net1_CMH/Scenario-506/Flows/link_122.csv')
plt.plot(df.index, df["Value"] )

# %%
df=pd.read_csv('C:/Users/cjoly/projet/Net1_CMH/Scenario-5/Flows/link_122.csv')
plt.plot(df.index, df["Value"] )

# %%
dp=pd.read_csv('C:/Users/cjoly/projet/Net1_CMH/Scenario-506/Pressures/Node_9.csv')
plt.plot(dp.index, dp["Value"] )

# %%
for i in range(1,1000):
    dp=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-{i}/Pressures/Node_9.csv')
    plt.plot(dp.index, dp["Value"])

# %% [markdown]
# Pressure on node 9 always null

# %%
dp=pd.read_csv('C:/Users/cjoly/projet/Net1_CMH/Scenario-2/Pressures/Node_2.csv')
plt.plot(dp.index, dp["Value"] )

# %%
dp=pd.read_csv('C:/Users/cjoly/projet/Net1_CMH/Scenario-2/Pressures/Node_10.csv')
plt.plot(dp.index, dp["Value"] )
