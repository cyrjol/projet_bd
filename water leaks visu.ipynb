# %%
import pandas as pd
import os
import glob

# %%
import matplotlib.pyplot as plt

# %%
fichiers = [i for i in os.listdir('C:/Users/cjoly/projet/Net1_CMH/') if os.path.isdir(os.path.join('C:/Users/cjoly/projet/Net1_CMH/', i))]

# %%
a = [i for i in os.listdir('C:/Users/cjoly/projet/Net1_CMH/') if os.path.isdir(os.path.join('C:/Users/cjoly/projet/Net1_CMH/', i))]

# %%
test ='Scenario-234'
test.find('-')
int(test[test.find('-') + 1:])
# Out:
# 234

# %%
os.listdir(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-19/Leaks')
# Out:
# []

# %%
fichiers=[]
e=0
for i in range(1,1001):
    if os.listdir(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-{i}/Leaks')==[] :
        e+=1
    else :
        fichiers.append(glob.glob(os.path.join(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-{i}/Leaks', "*info.csv")))
e
# Out:
# 259

# %%
fichiers
# Out:
# [['C:/Users/cjoly/projet/Net1_CMH/Scenario-1/Leaks\\Leak_13_info.csv'],
#  ['C:/Users/cjoly/projet/Net1_CMH/Scenario-2/Leaks\\Leak_31_info.csv'],
#  ['C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Leaks\\Leak_21_info.csv',
#   'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Leaks\\Leak_2_info.csv'],
#  ['C:/Users/cjoly/projet/Net1_CMH/Scenario-5/Leaks\\Leak_22_info.csv'],
#  ['C:/Users/cjoly/projet/Net1_CMH/Scenario-6/Leaks\\Leak_22_info.csv'],
#  ['C:/Users/cjoly/projet/Net1_CMH/Scenario-8/Leaks\\Leak_21_info.csv'],
#  ['C:/Users/cjoly/projet/Net1_CMH/Scenario-9/Leaks\\Leak_23_info.csv',
#   'C:/Users/cjoly/projet/Net1_CMH/Scenario-9/Leaks\\Leak_31_info.csv'],
#  ['C:/Users/cjoly/projet/Net1_CMH/Scenario-13/Leaks\\Leak_21_info.csv'],
#  ['C:/Users/cjoly/projet/Net1_CMH/Scenario-15/Leaks\\Leak_13_info.csv'],
#  ['C:/Users/cjoly/projet/Net1_CMH/Scenario-16/Leaks\\Leak_13_info.csv',
#   'C:/Users/cjoly/projet/Net1_CMH/Scenario-16/Leaks\\Leak_32_info.csv'],
# ...

# %%
for j in range (len(fichiers)) :
    for k in range(len(fichiers[j])):
        fichiers[j][k]=pd.read_csv(fichiers[j][k])

# %%
for j in range (len(fichiers)) :
    for k in range(len(fichiers[j])):
        fichiers[j][k].columns=["Description","Value"]

# %%
liste=[]
for j in range (len(fichiers)) :
    for k in range(len(fichiers[j])):
        if fichiers[j][k]['Value'][3]== ' abrupt' :
            liste.append([j,k])

# %%
liste_d=[]
for i in liste :
    liste_d.append(fichiers[i[0]][i[1]]['Value'][2])

# %%
liste
# Out:
# [[3, 0],
#  [4, 0],
#  [9, 0],
#  [9, 1],
#  [11, 0],
#  [12, 0],
#  [13, 0],
#  [14, 0],
#  [15, 0],
#  [16, 0],
#  [21, 0],
#  [24, 0],
#  [24, 1],
#  [25, 0],
#  [27, 1],
#  [29, 0],
#  [30, 0],
#  [31, 0],
#  [32, 0],
#  [32, 1],
#  [33, 0],
#  [36, 1],
#  [37, 1],
#  [38, 0],
#  [40, 1],
#  [41, 0],
#  [43, 0],
#  [46, 0],
#  [48, 0],
#  [51, 0],
#  [54, 0],
#  [55, 0],
#  [56, 0],
#  [57, 1],
#  [59, 0],
#  [59, 1],
#  [61, 0],
#  [62, 0],
#  [63, 0],
#  [64, 0],
#  [68, 0],
#  [68, 1],
#  [71, 0],
#  [75, 0],
#  [75, 1],
#  [77, 0],
#  [78, 0],
#  [78, 1],
#  [80, 0],
#  [81, 0],
#  [82, 0],
#  [83, 0],
#  [84, 0],
#  [85, 0],
#  [86, 0],
#  [87, 0],
#  [88, 0],
#  [92, 0],
#  [95, 0],
#  [96, 1],
#  [100, 0],
#  [100, 1],
#  [101, 0],
#  [104, 0],
#  [105, 0],
#  [106, 0],
#  [107, 1],
#  [108, 0],
#  [110, 0],
#  [111, 0],
#  [111, 1],
#  [112, 0],
#  [113, 0],
#  [115, 0],
#  [116, 0],
#  [117, 0],
#  [118, 0],
#  [118, 1],
#  [120, 0],
#  [123, 0],
#  [124, 0],
# ...

# %%
d=max(liste_d)
d
# Out:
# ' 0.199454885609'

# %%
a=liste_d.index(d)
a
# Out:
# 228

# %%
liste[228]
# Out:
# [355, 0]

# %%
fichiers[355]
# Out:
# [      Description             Value
#  0      Leak Node                 10
#  1      Leak Area    0.0312448807886
#  2  Leak Diameter     0.199454885609
#  3      Leak Type             abrupt
#  4     Leak Start               1027
#  5       Leak End               6404
#  6      Peak Time               1027]

# %%
#On affiche les demandes et les flux des noeuds et des jonctions dans l'ordre logique avec la structure du scénario
#les noeuds 2 et 9 ne sont pas présents sur le schéma, on peut s'interroger sur leurs significations réelles ? 
#peut etre au niveau de la source et de la pompe ?

# %%
dl=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-506/Leaks/Leak_10_demand.csv')
plt.plot(dl.index, dl["Value"] )

# %%
dd=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-506/Demands/Node_10.csv')
plt.plot(dd.index, dd["Value"] )

# %%
for i in range(1,1000):
    dp=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-{i}/Demands/Node_10.csv')
    plt.plot(dp.index, dp["Value"])

# %%
#cette valeur est toujours  nulle quelque soit le scénario on ne la prendra donc pas encompte
#on affiche les valeurs pour différents noeuds

# %%
dd=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-506/Demands/Node_2.csv')
plt.plot(dd.index, dd["Value"] )

# %%
#quasiment nulle mais on voit quand même la fuite

# %%
dd=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-506/Demands/Node_13.csv')
plt.plot(dd.index, dd["Value"] )

# %%
dd=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-506/Demands/Node_21.csv')
plt.plot(dd.index, dd["Value"] )

# %%
dd=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-506/Demands/Node_31.csv')
plt.plot(dd.index, dd["Value"] )

# %%
df=pd.read_csv('C:/Users/cjoly/projet/Net1_CMH/Scenario-506/Flows/link_10.csv')
plt.plot(df.index, df["Value"] )

# %%
df=pd.read_csv('C:/Users/cjoly/projet/Net1_CMH/Scenario-506/Flows/link_11.csv')
plt.plot(df.index, df["Value"] )

# %%
df=pd.read_csv('C:/Users/cjoly/projet/Net1_CMH/Scenario-506/Flows/link_111.csv')
plt.plot(df.index, df["Value"] )

# %%
df=pd.read_csv('C:/Users/cjoly/projet/Net1_CMH/Scenario-506/Flows/link_113.csv')
plt.plot(df.index, df["Value"] )

# %%
#on regarde maintenant la pression

# %%
dp=pd.read_csv('C:/Users/cjoly/projet/Net1_CMH/Scenario-506/Pressures/Node_9.csv')
plt.plot(dp.index, dp["Value"] )

# %%
for i in range(1,1000):
    dp=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-{i}/Pressures/Node_9.csv')
    plt.plot(dp.index, dp["Value"])

# %%
#valeur toujours nulle, on ne la prendra pas en compte

# %%
dp=pd.read_csv('C:/Users/cjoly/projet/Net1_CMH/Scenario-506/Pressures/Node_10.csv')
plt.plot(dp.index, dp["Value"] )

# %%
dp=pd.read_csv('C:/Users/cjoly/projet/Net1_CMH/Scenario-506/Pressures/Node_12.csv')
plt.plot(dp.index, dp["Value"] )

# %%
#les pressions ne sont pas exactement les mêmes (écart relatif <1%) à voir lesquelles on garde
