# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %%
#création dataset

# %%
n_2=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Demands/Node_2.csv')
n_9=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Demands/Node_9.csv')
n_11=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Demands/Node_11.csv')
n_12=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Demands/Node_12.csv')
n_13=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Demands/Node_13.csv')
n_21=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Demands/Node_21.csv')
n_22=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Demands/Node_22.csv')
n_23=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Demands/Node_23.csv')
n_31=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Demands/Node_31.csv')
n_32=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Demands/Node_32.csv')

# %%
n_2 =n_2.drop(n_2.columns[0], axis=1)
n_9 =n_9.drop(n_9.columns[0], axis=1)
n_11 =n_11.drop(n_11.columns[0], axis=1)
n_12 =n_12.drop(n_12.columns[0], axis=1)
n_13 =n_13.drop(n_13.columns[0], axis=1)
n_21 =n_21.drop(n_21.columns[0], axis=1)
n_22 =n_22.drop(n_22.columns[0], axis=1)
n_23 =n_23.drop(n_23.columns[0], axis=1)
n_31 =n_31.drop(n_31.columns[0], axis=1)
n_32 =n_32.drop(n_32.columns[0], axis=1)

# %%
df = n_2.merge(n_9, how='left', left_index=True, right_index=True)
df = df.merge(n_11, how='left', left_index=True, right_index=True)
df = df.merge(n_12, how='left', left_index=True, right_index=True)
df = df.merge(n_13, how='left', left_index=True, right_index=True)
df = df.merge(n_21, how='left', left_index=True, right_index=True)
df = df.merge(n_22, how='left', left_index=True, right_index=True)
df = df.merge(n_23, how='left', left_index=True, right_index=True)
df = df.merge(n_31, how='left', left_index=True, right_index=True)
df = df.merge(n_32, how='left', left_index=True, right_index=True)
# Out:
# C:\Users\cjoly\AppData\Local\Temp\ipykernel_20880\3832253817.py:3: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Value_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = df.merge(n_12, how='left', left_index=True, right_index=True)
# C:\Users\cjoly\AppData\Local\Temp\ipykernel_20880\3832253817.py:5: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Value_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = df.merge(n_21, how='left', left_index=True, right_index=True)
# C:\Users\cjoly\AppData\Local\Temp\ipykernel_20880\3832253817.py:7: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Value_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = df.merge(n_23, how='left', left_index=True, right_index=True)
# ...

# %%
columns=['Node 2','Node 9','Node 11','Node 12','Node 13','Node 21','Node 22','Node 23','Node 31','Node 32']

# %%
df.columns=columns

# %%
df.describe()
# Out:
#              Node 2        Node 9       Node 11       Node 12       Node 13  \
# count  17520.000000  17520.000000  17520.000000  17520.000000  17520.000000
# mean      -2.029315   -290.128562     35.497192     32.835000     23.235822
# std      108.167451    113.570620     11.176217     11.736765      7.820250
# min     -939.600000   -673.200000     10.800000      7.200000      7.200000
# 25%        0.000000   -338.400000     25.200000     25.200000     18.000000
# 50%        0.000000   -291.600000     36.000000     36.000000     25.200000
# 75%        0.000000   -216.000000     43.200000     39.600000     28.800000
# max      381.600000    -93.600000     68.400000     68.400000     46.800000
#
#             Node 21       Node 22       Node 23       Node 31       Node 32
# count  17520.000000  17520.000000  17520.000000  17520.000000  17520.000000
# mean      36.336575     47.000137     36.665548     23.903630     22.419452
# ...

# %%
corrmatrix = df.corr()
corr = corrmatrix.round(2)
corr
# Out:
#          Node 2  Node 9  Node 11  Node 12  Node 13  Node 21  Node 22  Node 23  \
# Node 2     1.00    0.05    -0.04    -0.05    -0.04     0.01    -0.04    -0.04
# Node 9     0.05    1.00    -0.54    -0.53    -0.50    -0.28    -0.48    -0.50
# Node 11   -0.04   -0.54     1.00     0.97     0.96     0.90     0.96     0.96
# Node 12   -0.05   -0.53     0.97     1.00     0.96     0.91     0.96     0.97
# Node 13   -0.04   -0.50     0.96     0.96     1.00     0.92     0.96     0.96
# Node 21    0.01   -0.28     0.90     0.91     0.92     1.00     0.93     0.92
# Node 22   -0.04   -0.48     0.96     0.96     0.96     0.93     1.00     0.96
# Node 23   -0.04   -0.50     0.96     0.97     0.96     0.92     0.96     1.00
# Node 31   -0.03   -0.30     0.90     0.91     0.92     0.95     0.93     0.92
# Node 32   -0.04   -0.34     0.91     0.92     0.93     0.95     0.94     0.93
#
#          Node 31  Node 32
# Node 2     -0.03    -0.04
# Node 9     -0.30    -0.34
# Node 11     0.90     0.91
# ...

# %%
col=['Node 2','Node 9','Node 12','Node 13','Node 21','Node 22','Node 23','Node 31','Node 32']
df=df.drop(columns=col,axis=1)

# %%
l_9=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Flows/Link_9.csv')
l_10=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Flows/Link_10.csv')
l_11=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Flows/Link_11.csv')
l_12=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Flows/Link_12.csv')
l_21=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Flows/Link_21.csv')
l_22=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Flows/Link_22.csv')
l_31=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Flows/Link_31.csv')
l_110=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Flows/Link_110.csv')
l_111=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Flows/Link_111.csv')
l_112=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Flows/Link_112.csv')
l_113=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Flows/Link_113.csv')
l_121=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Flows/Link_121.csv')
l_122=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Flows/Link_122.csv')

# %%
l_9 =l_9.drop(l_9.columns[0], axis=1)
l_10 =l_10.drop(l_10.columns[0], axis=1)
l_11 =l_11.drop(l_11.columns[0], axis=1)
l_12 =l_12.drop(l_12.columns[0], axis=1)
l_21 =l_21.drop(l_21.columns[0], axis=1)
l_22 =l_22.drop(l_22.columns[0], axis=1)
l_31 =l_31.drop(l_31.columns[0], axis=1)
l_110 =l_110.drop(l_110.columns[0], axis=1)
l_111 =l_111.drop(l_111.columns[0], axis=1)
l_112 =l_112.drop(l_112.columns[0], axis=1)
l_113 =l_113.drop(l_113.columns[0], axis=1)
l_121 =l_121.drop(l_121.columns[0], axis=1)
l_122 =l_122.drop(l_122.columns[0], axis=1)

# %%
df = df.merge(l_9, how='left', left_index=True, right_index=True)
df = df.merge(l_10, how='left', left_index=True, right_index=True)
df = df.merge(n_11, how='left', left_index=True, right_index=True)
df = df.merge(l_12, how='left', left_index=True, right_index=True)
df = df.merge(l_21, how='left', left_index=True, right_index=True)
df = df.merge(l_22, how='left', left_index=True, right_index=True)
df = df.merge(l_31, how='left', left_index=True, right_index=True)
df = df.merge(l_110, how='left', left_index=True, right_index=True)
df = df.merge(l_111, how='left', left_index=True, right_index=True)
df = df.merge(l_112, how='left', left_index=True, right_index=True)
df = df.merge(l_113, how='left', left_index=True, right_index=True)
df = df.merge(l_121, how='left', left_index=True, right_index=True)
df = df.merge(l_122, how='left', left_index=True, right_index=True)
# Out:
# C:\Users\cjoly\AppData\Local\Temp\ipykernel_20880\3415005905.py:4: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Value_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = df.merge(l_12, how='left', left_index=True, right_index=True)
# C:\Users\cjoly\AppData\Local\Temp\ipykernel_20880\3415005905.py:6: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Value_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = df.merge(l_22, how='left', left_index=True, right_index=True)
# C:\Users\cjoly\AppData\Local\Temp\ipykernel_20880\3415005905.py:8: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Value_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = df.merge(l_110, how='left', left_index=True, right_index=True)
# ...

# %%
df
# Out:
#        Node 11  Value_x  Value_y  Value_x  Value_y  Value_x  Value_y  Value_x  \
# 0         21.6    424.8    424.8     21.6     10.8     68.4     21.6     14.4
# 1         18.0    421.2    421.2     18.0      7.2     72.0     21.6     14.4
# 2         18.0    417.6    417.6     18.0      3.6     72.0     21.6     14.4
# 3         14.4    414.0    414.0     14.4      3.6     72.0     21.6     14.4
# 4         14.4    410.4    410.4     14.4      0.0     72.0     21.6     18.0
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 17515     36.0    255.6    255.6     36.0     32.4     18.0     28.8      7.2
# 17516     32.4    248.4    248.4     32.4     32.4     14.4     25.2      7.2
# 17517     32.4    234.0    234.0     32.4     28.8     14.4     21.6      7.2
# 17518     28.8    205.2    205.2     28.8     25.2     14.4     21.6      3.6
# 17519     25.2    190.8    190.8     25.2     25.2     10.8     21.6      3.6
#
# ...

# %%
columns=['Node 11','Link 9','Link 10','Link 11','Link 12','Link 21','Link 22','Link 31','Link 110','Link 111','Link 112','Link 113','Link 121','Link 122']

# %%
df.columns=columns

# %%
df.describe()
# Out:
#             Node 11        Link 9       Link 10       Link 11       Link 12  \
# count  17520.000000  17520.000000  17520.000000  17520.000000  17520.000000
# mean      35.497192    290.128562    290.128562     35.497192     35.144795
# std       11.176217    113.570620    113.570620     11.176217     17.517794
# min       10.800000     93.600000     93.600000     10.800000     -3.600000
# 25%       25.200000    216.000000    216.000000     25.200000     25.200000
# 50%       36.000000    291.600000    291.600000     36.000000     36.000000
# 75%       43.200000    338.400000    338.400000     43.200000     39.600000
# max       68.400000    673.200000    673.200000     68.400000    154.800000
#
#             Link 21       Link 22       Link 31      Link 110      Link 111  \
# count  17520.000000  17520.000000  17520.000000  17520.000000  17520.000000
# mean       6.002671     24.776301      3.588288      0.631027    102.597534
# ...

# %%
corrmatrix = df.corr()
corr = corrmatrix.round(2)
corr
# Out:
#           Node 11  Link 9  Link 10  Link 11  Link 12  Link 21  Link 22  \
# Node 11      1.00    0.54     0.54     1.00     0.50     0.14     0.53
# Link 9       0.54    1.00     1.00     0.54     0.69    -0.40    -0.13
# Link 10      0.54    1.00     1.00     0.54     0.69    -0.40    -0.13
# Link 11      1.00    0.54     0.54     1.00     0.50     0.14     0.53
# Link 12      0.50    0.69     0.69     0.50     1.00    -0.77    -0.43
# Link 21      0.14   -0.40    -0.40     0.14    -0.77     1.00     0.90
# Link 22      0.53   -0.13    -0.13     0.53    -0.43     0.90     1.00
# Link 31      0.19   -0.39    -0.39     0.19    -0.74     0.99     0.92
# Link 110     0.04    0.04     0.04     0.04     0.73    -0.80    -0.64
# Link 111     0.23    0.76     0.76     0.23     0.91    -0.87    -0.65
# Link 112     0.29    0.60     0.60     0.29     0.97    -0.90    -0.63
# Link 113     0.08    0.53     0.53     0.08     0.89    -0.97    -0.78
# ...

# %%
col=['Link 9','Link 10','Link 11','Link 12','Link 31','Link 110','Link 111','Link 112','Link 113','Link 121','Link 122']
df=df.drop(columns=col,axis=1)

# %%
p_2=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Pressures/Node_2.csv')
p_10=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Pressures/Node_10.csv')
p_11=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Pressures/Node_11.csv')
p_12=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Pressures/Node_12.csv')
p_13=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Pressures/Node_13.csv')
p_21=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Pressures/Node_21.csv')
p_22=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Pressures/Node_22.csv')
p_23=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Pressures/Node_23.csv')
p_31=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Pressures/Node_31.csv')
p_32=pd.read_csv(f'C:/Users/cjoly/projet/Net1_CMH/Scenario-3/Pressures/Node_32.csv')

# %%
p_2 =p_2.drop(p_2.columns[0], axis=1)
p_10 =p_10.drop(p_10.columns[0], axis=1)
p_11 =p_11.drop(p_11.columns[0], axis=1)
p_12 =p_12.drop(p_12.columns[0], axis=1)
p_13 =p_13.drop(p_13.columns[0], axis=1)
p_21 =p_21.drop(p_21.columns[0], axis=1)
p_22 =p_22.drop(p_22.columns[0], axis=1)
p_23 =p_23.drop(p_23.columns[0], axis=1)
p_31 =p_31.drop(p_31.columns[0], axis=1)
p_32 =p_32.drop(p_32.columns[0], axis=1)

# %%
df = df.merge(p_2, how='left', left_index=True, right_index=True)
df = df.merge(p_10, how='left', left_index=True, right_index=True)
df = df.merge(p_11, how='left', left_index=True, right_index=True)
df = df.merge(p_12, how='left', left_index=True, right_index=True)
df = df.merge(p_13, how='left', left_index=True, right_index=True)
df = df.merge(p_21, how='left', left_index=True, right_index=True)
df = df.merge(p_22, how='left', left_index=True, right_index=True)
df = df.merge(p_23, how='left', left_index=True, right_index=True)
df = df.merge(p_31, how='left', left_index=True, right_index=True)
df = df.merge(p_32, how='left', left_index=True, right_index=True)
# Out:
# C:\Users\cjoly\AppData\Local\Temp\ipykernel_20880\1470798153.py:4: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Value_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = df.merge(p_12, how='left', left_index=True, right_index=True)
# C:\Users\cjoly\AppData\Local\Temp\ipykernel_20880\1470798153.py:6: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Value_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = df.merge(p_21, how='left', left_index=True, right_index=True)
# C:\Users\cjoly\AppData\Local\Temp\ipykernel_20880\1470798153.py:8: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Value_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = df.merge(p_23, how='left', left_index=True, right_index=True)
# ...

# %%
columns=['Node 11','Link 21','Link 22','Pressure 2','Pressure 10','Pressure 11','Pressure 12','Pressure 13','Pressure 21','Pressure 22','Pressure 23','Pressure 31','Pressure 32']

# %%
df.columns=columns

# %%
df.describe()
# Out:
#             Node 11       Link 21       Link 22    Pressure 2   Pressure 10  \
# count  17520.000000  17520.000000  17520.000000  17520.000000  17520.000000
# mean      35.497192      6.002671     24.776301     44.393548    107.787291
# std       11.176217     65.479236     18.590121      4.094147     17.968475
# min       10.800000   -450.000000   -100.800000     15.921000     30.075000
# 25%       25.200000     10.800000     18.000000     45.720000    103.750500
# 50%       36.000000     18.000000     28.800000     45.720000    110.633000
# 75%       43.200000     21.600000     36.000000     45.720000    118.956500
# max       68.400000     90.000000     54.000000     45.720000    127.044000
#
#         Pressure 11   Pressure 12   Pressure 13   Pressure 21   Pressure 22  \
# count  17520.000000  17520.000000  17520.000000  17520.000000  17520.000000
# mean     105.287484    106.113558    106.750723    104.224109    106.636663
# ...

# %%
corrmatrix = df.corr()
corr = corrmatrix.round(2)
corr
# Out:
#              Node 11  Link 21  Link 22  Pressure 2  Pressure 10  Pressure 11  \
# Node 11         1.00     0.14     0.53        0.10        -0.34        -0.34
# Link 21         0.14     1.00     0.90        0.51         0.51         0.51
# Link 22         0.53     0.90     1.00        0.50         0.30         0.30
# Pressure 2      0.10     0.51     0.50        1.00         0.80         0.80
# Pressure 10    -0.34     0.51     0.30        0.80         1.00         1.00
# Pressure 11    -0.34     0.51     0.30        0.80         1.00         1.00
# Pressure 12    -0.35     0.47     0.27        0.80         1.00         1.00
# Pressure 13    -0.35     0.51     0.30        0.80         1.00         1.00
# Pressure 21    -0.28     0.70     0.49        0.81         0.96         0.96
# Pressure 22    -0.34     0.55     0.33        0.81         1.00         1.00
# Pressure 23    -0.35     0.54     0.33        0.80         1.00         1.00
# ...

# %%
col=['Pressure 2','Pressure 11','Pressure 12','Pressure 13','Pressure 21','Pressure 22','Pressure 23','Pressure 31','Pressure 32']
df=df.drop(columns=col,axis=1)

# %%
df
# Out:
#        Node 11  Link 21  Link 22  Pressure 10
# 0         21.6     68.4     21.6       89.705
# 1         18.0     72.0     21.6       90.406
# 2         18.0     72.0     21.6       91.089
# 3         14.4     72.0     21.6       91.795
# 4         14.4     72.0     21.6       92.462
# ...        ...      ...      ...          ...
# 17515     36.0     18.0     28.8      114.619
# 17516     32.4     14.4     25.2      115.621
# 17517     32.4     14.4     21.6      117.158
# 17518     28.8     14.4     21.6      119.785
# 17519     25.2     10.8     21.6      120.940
#
# [17520 rows x 4 columns]

# %%
corrmatrix = df.corr()
corr = corrmatrix.round(2)
corr
# Out:
#              Node 11  Link 21  Link 22  Pressure 10
# Node 11         1.00     0.14     0.53        -0.34
# Link 21         0.14     1.00     0.90         0.51
# Link 22         0.53     0.90     1.00         0.30
# Pressure 10    -0.34     0.51     0.30         1.00

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(df)
df=pd.DataFrame(scaler.transform(df))

# %%
columns=['Node 11','Link 21','Link 22','Pressure 10']
df.columns=columns

# %%
df
# Out:
#         Node 11   Link 21   Link 22  Pressure 10
# 0     -1.243497  0.952960 -0.170865    -1.006363
# 1     -1.565618  1.007941 -0.170865    -0.967349
# 2     -1.565618  1.007941 -0.170865    -0.929337
# 3     -1.887740  1.007941 -0.170865    -0.890045
# 4     -1.887740  1.007941 -0.170865    -0.852923
# ...         ...       ...       ...          ...
# 17515  0.044990  0.183229  0.216449     0.380216
# 17516 -0.277131  0.128248  0.022792     0.435982
# 17517 -0.277131  0.128248 -0.170865     0.521523
# 17518 -0.599253  0.128248 -0.170865     0.667728
# 17519 -0.921375  0.073267 -0.170865     0.732009
#
# [17520 rows x 4 columns]

# %%
df.to_csv('C:/Users/cjoly/projet/Net1_CMH/Scenario-3/df_min.csv')

# %%
labels =pd.read_csv('C:/Users/cjoly/projet/Net1_CMH/Scenario-507/Labels.csv')

# %%
labels.describe()
# Out:
#               Index         Label
# count  17520.000000  17520.000000
# mean    8760.500000      0.337386
# std     5057.732694      0.472831
# min        1.000000      0.000000
# 25%     4380.750000      0.000000
# 50%     8760.500000      0.000000
# 75%    13140.250000      1.000000
# max    17520.000000      1.000000

# %%
time = pd.read_csv('C:/Users/cjoly/projet/Net1_CMH/Scenario-505/Timestamps.csv')

# %%
labels.insert(0,"timestamp" , pd.to_datetime(time['Timestamp']))

# %%
labels.to_csv('C:/Users/cjoly/projet/Net1_CMH/Scenario-507/y.csv')
